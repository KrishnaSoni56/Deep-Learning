# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/home/krishna/Csv_files/csv_1/click.csv")

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
df =df.drop(columns= "Timestamp")

# %%
encode_list = ['Ad Topic Line' , 'City' , 'Gender' , 'Country']

df = pd.get_dummies(df , columns = encode_list)

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site     0
# Age                          0
# Area Income                  0
# Daily Internet Usage         0
# Clicked on Ad                0
#                             ..
# Country_Wallis and Futuna    0
# Country_Western Sahara       0
# Country_Yemen                0
# Country_Zambia               0
# Country_Zimbabwe             0
# Length: 1294, dtype: int64

# %%
import tensorflow as tf
from  tensorflow import keras
from keras import Sequential
from keras.layers import Dense
# Out:
# 2024-09-04 13:44:40.190015: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 13:44:40.194141: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 13:44:40.201843: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 13:44:40.215007: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 13:44:40.218830: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#    Clicked on Ad  Ad Topic Line_Adaptive 24hour Graphic Interface  \
# 0              0                                            False
# 1              0                                            False
# 2              0                                            False
# 3              0                                            False
# 4              1                                            False
#
#    Ad Topic Line_Adaptive contextually-based methodology  \
# 0                                              False
# ...

# %%
X = df.drop(columns = ['Clicked on Ad'], axis =  1)
y = df['Clicked on Ad']

# %%
sc = StandardScaler()

X_scaled = sc.fit_transform(X)

# %%
X_train , X_test , y_train , y_test = train_test_split(X_scaled , y , test_size= 0.2 , random_state= 34)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64 , activation= 'relu' , input_dim = X_train.shape[1]) ,
    tf.keras.layers.Dense(64 , activation = 'relu' ) ,
    tf.keras.layers.Dense(1 , activation = 'sigmoid')
])
# Out:
# /home/krishna/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate= 0.001) ,
             loss = 'binary_crossentropy' ,
             metrics= ['Accuracy'])

model.fit(X_train, y_train , epochs= 50 , batch_size = 32)

loss , acc = model.evaluate(X_test , y_test)
print('Loss', loss)
print('Accuracy',acc*100)
# Out:
# 2024-09-04 13:44:42.268876: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 41376000 exceeds 10% of free system memory.
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - Accuracy: 0.7307 - loss: 0.5322
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9177 - loss: 0.2123
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9437 - loss: 0.1537
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9496 - loss: 0.1341
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9607 - loss: 0.1063
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9600 - loss: 0.0991
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9676 - loss: 0.0801
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9702 - loss: 0.0733
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Accuracy: 0.9749 - loss: 0.0661
# Epoch 10/50
# ...
