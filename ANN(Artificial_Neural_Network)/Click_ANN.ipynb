# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/home/krishna/Csv_files/csv_1/click.csv")

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# 1                     Singapore  2016-01-16 17:56:05              0
# 2                    Guadeloupe  2016-06-29 10:50:45              0
# 3                        Zambia  2016-06-21 14:32:32              0
# 4                         Qatar  2016-07-21 10:54:35              1

# %%
df =df.drop(columns= "Timestamp")

# %%
encode_list = ['Ad Topic Line' , 'City' , 'Gender' , 'Country']

df = pd.get_dummies(df , columns = encode_list)

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site     0
# Age                          0
# Area Income                  0
# Daily Internet Usage         0
# Clicked on Ad                0
#                             ..
# Country_Wallis and Futuna    0
# Country_Western Sahara       0
# Country_Yemen                0
# Country_Zambia               0
# Country_Zimbabwe             0
# Length: 1294, dtype: int64

# %%
import tensorflow as tf
from  tensorflow import keras
from keras import Sequential
from keras.layers import Dense
# Out:
# 2024-09-04 12:52:01.496129: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 12:52:01.499187: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 12:52:01.506642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 12:52:01.519475: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 12:52:01.523190: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 12:52:01.533893: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 12:52:02.241764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#    Clicked on Ad  Ad Topic Line_Adaptive 24hour Graphic Interface  \
# 0              0                                            False
# 1              0                                            False
# 2              0                                            False
# 3              0                                            False
# 4              1                                            False
#
#    Ad Topic Line_Adaptive contextually-based methodology  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Ad Topic Line_Advanced 24/7 productivity  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Ad Topic Line_Advanced heuristic firmware  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    Ad Topic Line_Advanced local task-force  ...  \
# 0                                    False  ...
# 1                                    False  ...
# 2                                    False  ...
# 3                                    False  ...
# 4                                    False  ...
#
#    Country_United States of America  Country_Uruguay  Country_Uzbekistan  \
# 0                             False            False               False
# 1                             False            False               False
# 2                             False            False               False
# 3                             False            False               False
# 4                             False            False               False
#
#    Country_Vanuatu  Country_Venezuela  Country_Wallis and Futuna  \
# 0            False              False                      False
# 1            False              False                      False
# 2            False              False                      False
# 3            False              False                      False
# 4            False              False                      False
#
#    Country_Western Sahara  Country_Yemen  Country_Zambia  Country_Zimbabwe
# 0                   False          False           False             False
# 1                   False          False           False             False
# 2                   False          False           False             False
# 3                   False          False            True             False
# 4                   False          False           False             False
#
# [5 rows x 1294 columns]

# %%
X = df.drop(columns = ['Clicked on Ad'], axis =  1)
y = df['Clicked on Ad']

# %%
sc = StandardScaler()

X_scaled = sc.fit_transform(X)

# %%
X_train , X_test , y_train , y_test = train_test_split(X_scaled , y , test_size= 0.2 , random_state= 34)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(